# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class
import matplotlib as plt

# %matplotlib inline

AV = AutoViz_Class()

viz = AV.AutoViz("music.csv", sep=",")
# Out:
# Shape of your Data Set loaded: (18, 3)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_0cec2_row0_col0, #T_0cec2_row0_col4, #T_0cec2_row1_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0cec2_row0_col1, #T_0cec2_row0_col6, #T_0cec2_row1_col1, #T_0cec2_row1_col6, #T_0cec2_row2_col1, #T_0cec2_row2_col6 {
#   font-family: Segoe UI;
# }
# #T_0cec2_row0_col2, #T_0cec2_row0_col3, #T_0cec2_row0_col5, #T_0cec2_row1_col2, #T_0cec2_row1_col3, #T_0cec2_row2_col0, #T_0cec2_row2_col2, #T_0cec2_row2_col3, #T_0cec2_row2_col4, #T_0cec2_row2_col5 {
#   background-color: #fff5f0;
# ...
